# %% [markdown]
# # Regresión con Árboles de Decisión

# %% [markdown]
# ## Importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importar el data set

# %%
dataset = pd.read_csv('../data/Position_Salaries.csv')
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
# TODO: Define las variables X e y
# Tip: En este dataset queremos predecir 'Salary' basado en 'Level'
# X debe incluir solo las columnas numéricas relevantes (excluir Position y Salary)
# y debe ser la columna objetivo 'Salary'

X = # Tu código aquí (usa drop() para excluir columnas no necesarias)
y = # Tu código aquí (selecciona la columna Salary)

# %%
# Verificar las dimensiones y tipos de datos
print("Forma de X:", X.shape)
print("Forma de y:", y.shape)
print("\nPrimeras filas de X:")
print(X.head())
print("\nPrimeras filas de y:")
print(y.head())

# %% [markdown]
# ## División del dataset en entrenamiento y prueba

# %%
# TODO: Importar train_test_split
# Tip: Lo necesitas de sklearn.model_selection

# Tu código aquí

# %%
# TODO: Dividir el dataset en conjuntos de entrenamiento y prueba
# Tip: Usa test_size=0.3 y random_state=0 para reproducibilidad

X_train, X_test, y_train, y_test = # Tu código aquí

# Verificar las divisiones
print("Tamaño del conjunto de entrenamiento:", X_train.shape[0])
print("Tamaño del conjunto de prueba:", X_test.shape[0])

# %% [markdown]
# ## Crear y entrenar el modelo de árbol de decisión

# %%
# TODO: Importar DecisionTreeRegressor
# Tip: Lo necesitas de sklearn.tree

# Tu código aquí

# %%
# TODO: Crear el modelo de árbol de decisión
# Tip: Usa random_state=0 para resultados reproducibles

regression = # Tu código aquí

# %%
# TODO: Entrenar el modelo con los datos de entrenamiento
# Tip: Usa el método .fit() con X_train e y_train

# Tu código aquí

print("✅ Modelo entrenado exitosamente!")

# %% [markdown]
# ## Realizar predicciones y evaluar el modelo

# %%
# TODO: Realizar predicciones en el conjunto de prueba
# Tip: Usa el método .predict() con X_test

y_pred = # Tu código aquí

# Mostrar algunas predicciones vs valores reales
print("Comparación de predicciones vs valores reales:")
print("=" * 50)
for i in range(len(y_test)):
    print(f"Real: {y_test.iloc[i].values[0]:,.0f} | Predicción: {y_pred[i]:,.0f}")

# %%
# TODO: Importar métricas para evaluar el modelo
# Tip: Necesitas mean_squared_error, mean_absolute_error de sklearn.metrics
# También necesitas math para calcular la raíz cuadrada

# Tu código aquí

# %%
# TODO: Calcular métricas de evaluación
# Tip: RMSE = raíz cuadrada del MSE, MAE = error absoluto medio

rmse = # Tu código aquí (usa math.sqrt y mean_squared_error)
mae = # Tu código aquí (usa mean_absolute_error)

print("📊 Métricas de evaluación del modelo:")
print(f"RMSE: {format(rmse, '.2f')}")
print(f"MAE: {format(mae, '.2f')}")

# Explicación de las métricas
print("\n💡 ¿Qué significan estas métricas?")
print("• RMSE: Error cuadrático medio (menor es mejor)")
print("• MAE: Error absoluto medio (menor es mejor)")

# %% [markdown]
# ## Visualización del árbol de decisión
#
# Una de las grandes ventajas de los árboles de decisión es que son interpretables. Podemos visualizar cómo toma las decisiones.

# %%
# TODO: Importar tree para la visualización
# Tip: Lo necesitas de sklearn

# Tu código aquí

# %%
# TODO: Crear la visualización del árbol
# Tip: Usa tree.plot_tree() con los siguientes parámetros:
# - regression: el modelo entrenado
# - feature_names: ["Level"] 
# - class_names: ["Salary"]
# - filled: True

fig = plt.figure(figsize=(25, 20))
arbol = # Tu código aquí

plt.title("🌳 Árbol de Decisión para Predicción de Salarios", fontsize=16, pad=20)
plt.show()

print("💡 Cómo leer el árbol:")
print("• Cada caja muestra una regla de decisión")
print("• Los valores en las hojas son las predicciones finales")
print("• El color indica la intensidad del valor predicho")

# %% [markdown]
# ## Visualización de predicciones
#
# Comparemos visualmente las predicciones del árbol con los valores reales.

# %%
# TODO: Crear un gráfico de dispersión que compare predicciones vs valores reales
# Tip: Crea un scatter plot donde X=valores reales, Y=predicciones
# Una línea diagonal perfecta indicaría predicciones exactas

plt.figure(figsize=(10, 8))

# Tu código aquí para el scatter plot
# Tu código aquí para agregar una línea diagonal (y=x)

plt.xlabel('Valores Reales')
plt.ylabel('Predicciones')
plt.title('📊 Predicciones vs Valores Reales - Árbol de Decisión')
plt.legend(['Línea perfecta (y=x)', 'Predicciones'])

# Agregar información del modelo
plt.text(0.05, 0.95, f'RMSE: {rmse:.2f}\\nMAE: {mae:.2f}', 
         transform=plt.gca().transAxes, fontsize=12, 
         bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue"))

plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Ejercicios adicionales y experimentación

# %%
# Reto 1: Experimentar con diferentes parámetros del árbol
# Los árboles de decisión tienen varios hiperparámetros que puedes ajustar:

print("🔬 Experimentando con diferentes configuraciones de árboles:")
print("=" * 60)

# Diferentes configuraciones para probar
configs = [
    {"max_depth": 3, "name": "Árbol poco profundo"},
    {"max_depth": 10, "name": "Árbol profundo"},
    {"min_samples_split": 5, "name": "Mínimo 5 muestras para dividir"},
    {"min_samples_leaf": 3, "name": "Mínimo 3 muestras por hoja"},
]

results = []

for config in configs:
    print(f"\\n🌳 {config['name']}:")
    
    # TODO: Crear un nuevo árbol con estos parámetros
    # Tip: Pasa los parámetros al DecisionTreeRegressor
    # Ejemplo: DecisionTreeRegressor(max_depth=3, random_state=0)
    
    tree_model = # Tu código aquí
    
    # TODO: Entrenar el modelo
    # Tu código aquí
    
    # TODO: Hacer predicciones
    # Tu código aquí
    
    # TODO: Calcular métricas
    # Tu código aquí
    
    # Almacenar resultados para comparación
    # results.append((config['name'], rmse_new, mae_new))

# %%
# Reto 2: Predicciones para nuevos valores
# Vamos a usar nuestro modelo para predecir salarios de nuevos niveles

print("🔮 Haciendo predicciones para nuevos valores:")
print("=" * 50)

# TODO: Crear nuevos valores para predecir
# Tip: Puedes crear un array con valores intermedios, como 1.5, 2.5, etc.
nuevos_niveles = # Tu código aquí (ejemplo: np.array([[1.5], [2.5], [3.5], [4.5]]))

# TODO: Hacer predicciones para estos nuevos valores
# Tu código aquí

print("\\nPredicciones para niveles intermedios:")
for i, nivel in enumerate(nuevos_niveles):
    # print(f"Nivel {nivel[0]}: ${prediccion_nueva[i]:,.0f}")
    pass  # Reemplaza con tu código

# TODO: Crear una visualización que incluya:
# 1. Los datos originales
# 2. Las nuevas predicciones
# 3. Una línea conectando las predicciones para mostrar la forma del modelo

plt.figure(figsize=(12, 8))
# Tu código aquí para una visualización completa
plt.title("🎯 Datos Originales vs Nuevas Predicciones")
plt.xlabel("Nivel")
plt.ylabel("Salario")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Preguntas para reflexionar
#
# Después de completar el ejercicio, reflexiona sobre estas preguntas:

# %% [markdown]
# ### 🤔 Análisis y comprensión
#
# 1. **¿Cómo se comporta el árbol de decisión comparado con la regresión lineal?**
#    - ¿Es mejor o peor para este dataset?
#    - ¿Qué ventajas y desventajas observas?
#
# 2. **Interpretabilidad del modelo:**
#    - ¿Puedes entender las reglas que sigue el árbol?
#    - ¿Qué nivel de experiencia requiere más salario según el modelo?
#
# 3. **Efecto de los hiperparámetros:**
#    - ¿Qué sucede cuando limitas la profundidad del árbol?
#    - ¿Observas signos de overfitting con árboles muy profundos?
#
# 4. **Características de las predicciones:**
#    - ¿Las predicciones del árbol son suaves o escalonadas?
#    - ¿Por qué ocurre esto?
#
# 5. **Aplicabilidad práctica:**
#    - ¿En qué situaciones preferirías un árbol de decisión sobre otros modelos?
#    - ¿Para qué tipos de problemas son especialmente útiles?
#
# ### 💡 Conceptos clave aprendidos
#
# - ✅ Los árboles de decisión son **interpretables** y fáciles de visualizar
# - ✅ Pueden capturar **relaciones no lineales** sin transformaciones de features
# - ✅ Son susceptibles al **overfitting** si no se controlan adecuadamente
# - ✅ Las predicciones tienen forma **escalonada** debido a su naturaleza
# - ✅ Son ideales para problemas donde la **interpretabilidad** es crucial
