# %% [markdown]
# # REGRESIÓN LINEAL SIMPLE

# %% [markdown]
# # Importar las librerías
#
# **💡 TIP:** Para una regresión lineal simple necesitarás:
# - NumPy para operaciones numéricas
# - Matplotlib para visualización
# - Pandas para manejo de datos
# - De sklearn: `train_test_split`, `LinearRegression` y opcionalmente `StandardScaler`
#
# **🎯 OBJETIVO:** Importar todas las librerías necesarias para realizar regresión lineal simple

# %%
# TODO: Importa las librerías básicas (numpy, matplotlib, pandas)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# TODO: Importa train_test_split de sklearn.model_selection
from sklearn.model_selection import train_test_split

# TODO: Importa StandardScaler de sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# TODO: Importa LinearRegression de sklearn.linear_model
from sklearn.linear_model import LinearRegression

# BONUS: Configuración para mejorar visualizaciones (opcional)
plt.style.use('default')  # Cambia por 'seaborn-v0_8' si prefieres
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# # Cargar y Explorar el Dataset
#
# **🔍 ANÁLISIS EXPLORATORIO INICIAL**
#
# Como data scientists, siempre comenzamos cargando y explorando nuestros datos. Este dataset contiene información sobre salarios en función de años de experiencia - un caso clásico para regresión lineal simple.
#
# **💡 TIP:** Usa `pd.read_csv()` para cargar el dataset desde `../data/Salary_Data.csv`

# %%
# TODO: Cargar el dataset desde '../data/Salary_Data.csv'
dataset = # Tu código aquí

# TODO: Explora la estructura del dataset
print("Forma del dataset:", dataset.shape)
print("\nPrimeras 5 filas:")
print(dataset.head())

# TODO: Muestra información estadística básica
print("\nInformación estadística:")
print(dataset.describe())

# TODO: Define X (variable independiente) como todas las columnas excepto la última
# TIP: Usa .iloc[:, :-1].values
X = # Tu código aquí

# TODO: Define y (variable dependiente) como la última columna
# TIP: Usa .iloc[:, 1].values o .iloc[:, -1].values
y = # Tu código aquí

print(f"\nForma de X: {X.shape}")
print(f"Forma de y: {y.shape}")

# %% [markdown]
# # Dividir el Dataset en Entrenamiento y Test
#
# **🎯 ESTRATEGIA DE VALIDACIÓN**
#
# La división train-test es crucial para evaluar el rendimiento real de nuestro modelo.
#
# **💡 TIPS:**
# - Usa una proporción típica: 67% entrenamiento, 33% test
# - Establece `random_state=0` para reproducibilidad
# - `test_size=1/3` o `test_size=0.33` son equivalentes

# %%
# TODO: Divide el dataset usando train_test_split
# TIP: train_test_split(X, y, test_size=?, random_state=0)
X_train, X_test, y_train, y_test = # Tu código aquí

# TODO: Verifica que la división fue correcta
print("Tamaños después de la división:")
print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")

# BONUS: Calcula el porcentaje en test
porcentaje_test = # Tu código aquí (len(X_test)/(len(X_train)+len(X_test))*100)
print(f"Porcentaje en test: {porcentaje_test:.1f}%")

# %% [markdown]
# # Crear y Entrenar el Modelo de Regresión Lineal
#
# **🧠 ENTRENAMIENTO DEL MODELO**
#
# Utilizamos el algoritmo de **mínimos cuadrados ordinarios (OLS)** que minimiza la suma de errores cuadráticos.
#
# **📊 CONCEPTOS CLAVE:**
# - En regresión lineal simple buscamos: **y = β₀ + β₁x + ε**
# - β₀ = intercept (donde la línea cruza el eje Y)
# - β₁ = pendiente (cuánto cambia Y por cada unidad de X)
# - ε = error aleatorio
#
# **💡 TIP:** Usa `LinearRegression()` y su método `.fit()`

# %%
# TODO: Crea una instancia del modelo LinearRegression
regression = # Tu código aquí

# TODO: Entrena el modelo con los datos de entrenamiento
# TIP: Usa el método .fit() con X_train y y_train
# Tu código aquí

# TODO: Extrae los parámetros del modelo entrenado
print("Parámetros del modelo:")
print(f"Intercept (β₀): {regression.intercept_:.2f}")
print(f"Coeficiente (β₁): {regression.coef_[0]:.2f} - Años de experiencia")

# TODO: Muestra la ecuación de la recta
print(f"\nEcuación de la recta: y = {regression.intercept_:.2f} + {regression.coef_[0]:.2f}x")

# TODO: Interpreta el coeficiente
print("Interpretación: Por cada año adicional de experiencia, el salario aumenta ${:.2f}".format(regression.coef_[0]))

# %% [markdown]
# # Realizar Predicciones sobre el Conjunto de Test
#
# **🔮 EVALUACIÓN DEL MODELO**
#
# Ahora aplicamos nuestro modelo entrenado a datos que nunca ha visto (test set) para evaluar su capacidad de **generalización**.
#
# **💡 TIP:** Usa el método `.predict()` del modelo entrenado

# %%
# TODO: Genera predicciones para el conjunto de test
# TIP: usa regression.predict(X_test)
y_pred = # Tu código aquí

# TODO: Compara algunas predicciones con valores reales
print("Comparación de predicciones vs valores reales (primeras 5 muestras):")
print("Años Exp. | Salario Real | Salario Pred. | Error")
print("-" * 50)

# TODO: Completa el loop para mostrar comparaciones
for i in range(min(5, len(X_test))):
    error = # Tu código aquí (y_test[i] - y_pred[i])
    print(f"{X_test[i][0]:8.1f} | ${y_test[i]:10.0f} | ${y_pred[i]:11.0f} | ${error:6.0f}")

# %% [markdown]
# # Visualizar los Resultados - Conjunto de Entrenamiento
#
# **📊 ANÁLISIS VISUAL - TRAINING SET**
#
# Esta visualización muestra qué tan bien nuestro modelo se ajusta a los datos de entrenamiento.
# - **Puntos rojos:** datos originales
# - **Línea azul:** función de regresión aprendida
#
# **⚠️ IMPORTANTE:** Un buen ajuste en training no garantiza buen rendimiento en test (posible overfitting)

# %%
# TODO: Crea la visualización del ajuste en datos de entrenamiento
plt.figure(figsize=(10, 6))

# TODO: Dibuja los puntos de los datos reales
# TIP: plt.scatter(X_train, y_train, color="red", alpha=0.7, s=50, label="Datos reales")
# Tu código aquí

# TODO: Dibuja la línea de regresión
# TIP: plt.plot(X_train, regression.predict(X_train), color="blue", linewidth=2, label="Línea de regresión")
# Tu código aquí

# TODO: Añade título y etiquetas
plt.title("Sueldo vs Años de Experiencia (Conjunto de Entrenamiento)", fontsize=14, fontweight='bold')
plt.xlabel("Años de Experiencia", fontsize=12)
plt.ylabel("Sueldo (en $)", fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Visualizar los Resultados - Conjunto de Test
#
# **📊 ANÁLISIS VISUAL - TEST SET (MÁS IMPORTANTE)**
#
# Esta es la visualización más importante - muestra el rendimiento real de nuestro modelo en datos no vistos. La proximidad entre puntos y línea indica la calidad de nuestras predicciones.
#
# **🎯 OBJETIVO:** Esta gráfica nos dice qué tan bien generalizará nuestro modelo a datos nuevos

# %%
# TODO: Crea la visualización del rendimiento en datos de test
plt.figure(figsize=(10, 6))

# TODO: Dibuja los valores reales del test set
# TIP: plt.scatter(X_test, y_test, color="red", alpha=0.7, s=50, label="Valores reales")
# Tu código aquí

# TODO: Dibuja las predicciones del test set
# TIP: plt.plot(X_test, regression.predict(X_test), color="blue", linewidth=2, label="Predicciones")
# Tu código aquí

# TODO: Completa el gráfico
plt.title("Sueldo vs Años de Experiencia (Conjunto de Testing)", fontsize=14, fontweight='bold')
plt.xlabel("Años de Experiencia", fontsize=12)
plt.ylabel("Sueldo (en $)", fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Evaluación del Modelo - Métricas de Rendimiento
#
# **📊 MÉTRICAS CLAVE PARA REGRESIÓN:**
#
# 1. **R² Score (Coeficiente de Determinación):** % de variabilidad explicada por el modelo
#    - Rango: 0 a 1 (más cerca de 1 = mejor)
#    - Interpretación: R² = 0.85 significa que el modelo explica 85% de la variabilidad
#
# 2. **MSE (Mean Squared Error):** Error cuadrático medio
# 3. **RMSE (Root Mean Squared Error):** Raíz del MSE (misma unidad que Y)
# 4. **MAE (Mean Absolute Error):** Error absoluto promedio
#
# **💡 TIP:** Importa las métricas desde `sklearn.metrics`

# %%
# TODO: Importa las métricas necesarias de sklearn.metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

# TODO: Calcula el R² score
# TIP: r2_score(y_true=y_test, y_pred=y_pred)
r2 = # Tu código aquí

# TODO: Calcula MSE, RMSE y MAE
mse = # Tu código aquí (mean_squared_error)
rmse = # Tu código aquí (sqrt(mse))
mae = # Tu código aquí (mean_absolute_error)

print("=== MÉTRICAS DE EVALUACIÓN DEL MODELO ===")
print(f"R² Score: {r2:.4f}")
print(f"  Interpretación: El modelo explica {r2*100:.1f}% de la variabilidad en los salarios")

print(f"\nMSE (Error Cuadrático Medio): ${mse:,.0f}")
print(f"RMSE (Raíz del ECM): ${rmse:,.0f}")
print(f"  Interpretación: En promedio, nuestras predicciones se desvían ${rmse:,.0f}")

print(f"\nMAE (Error Absoluto Medio): ${mae:,.0f}")
print(f"  Interpretación: Error promedio absoluto de ${mae:,.0f}")

# TODO: Evaluación cualitativa del modelo (completa las condiciones)
if r2 > 0.8:
    print(f"\n✅ Excelente ajuste del modelo (R² = {r2:.3f})")
elif r2 > 0.6:
    print(f"\n✅ Buen ajuste del modelo (R² = {r2:.3f})")
elif r2 > 0.4:
    print(f"\n⚠️ Ajuste moderado del modelo (R² = {r2:.3f})")
else:
    print(f"\n❌ Ajuste pobre del modelo (R² = {r2:.3f})")

# %% [markdown]
# # 🎯 Ejercicios Adicionales (BONUS)
#
# **🚀 RETOS PARA PROFUNDIZAR:**
#
# 1. **Análisis de Residuales:**
#    - Calcula los errores (residuales = y_test - y_pred)
#    - Crea un histogram de los residuales
#    - ¿Siguen una distribución normal?
#
# 2. **Predicción Personalizada:**
#    - Predice el salario para alguien con 7.5 años de experiencia
#    - Usa `regression.predict([[7.5]])`
#
# 3. **Interpretación de Negocio:**
#    - ¿Cuál sería el salario mínimo según tu modelo (0 años experiencia)?
#    - ¿A partir de cuántos años se alcanzaría un salario de $100,000?
#
# **💡 TIP:** Estos ejercicios te ayudarán a entender mejor el modelo y sus limitaciones.

# %%
# BONUS 1: Análisis de Residuales
# TODO: Calcula los residuales (errores)
residuales = # Tu código aquí (y_test - y_pred)

print("Análisis de Residuales:")
print(f"Error promedio (debería ser ~0): {residuales.mean():.2f}")
print(f"Error estándar: {residuales.std():.2f}")
print(f"Error máximo: {residuales.max():.2f}")
print(f"Error mínimo: {residuales.min():.2f}")

# TODO: Crea un histograma de los residuales
plt.figure(figsize=(10, 6))
plt.hist(residuales, bins=10, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribución de Residuales')
plt.xlabel('Error (Residual)')
plt.ylabel('Frecuencia')
plt.axvline(x=0, color='red', linestyle='--', label='Error = 0')
plt.legend()
plt.show()

# %%
# BONUS 2: Predicciones Personalizadas
# TODO: Predice el salario para 7.5 años de experiencia
prediccion_75_anos = # Tu código aquí (regression.predict([[7.5]]))
print(f"Salario predicho para 7.5 años de experiencia: ${prediccion_75_anos[0]:,.0f}")

# BONUS 3: Interpretaciones de Negocio
# TODO: ¿Cuál sería el salario con 0 años de experiencia?
salario_0_anos = # Tu código aquí (regression.intercept_)
print(f"Salario base (0 años experiencia): ${salario_0_anos:,.0f}")

# TODO: ¿Cuántos años se necesitan para ganar $100,000?
# Pista: Despejar x de la ecuación: 100000 = intercept + coef * x
# x = (100000 - intercept) / coef
anos_para_100k = # Tu código aquí
print(f"Años necesarios para ganar $100,000: {anos_para_100k:.1f} años")

# %% [markdown]
# # 📝 Conclusiones del Análisis
#
# **🎯 REFLEXIONES FINALES:**
#
# Después de completar este ejercicio, deberías poder responder:
#
# 1. **¿Cómo es el rendimiento de tu modelo?**
#    - Revisa el R² score obtenido
#    - ¿Es aceptable para un problema de negocio real?
#
# 2. **¿Qué limitaciones tiene este modelo?**
#    - Solo considera una variable (años de experiencia)
#    - Asume relación perfectamente lineal
#    - No captura factores como educación, ubicación, industria, etc.
#
# 3. **¿Qué patrones observas en los residuales?**
#    - ¿Son aleatorios o hay patrones?
#    - ¿Hay outliers significativos?
#
# **🚀 PRÓXIMOS PASOS EN TU APRENDIZAJE:**
# - Regresión múltiple con más variables
# - Validación de supuestos estadísticos
# - Técnicas de regularización (Ridge, Lasso)
# - Modelos no lineales
#
# **💼 APLICACIÓN PRÁCTICA:**
# Este modelo puede usarse para estimaciones iniciales de salarios, pero debería complementarse con otros factores para decisiones importantes de HR.
