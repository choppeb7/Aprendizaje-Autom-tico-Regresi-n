# %% [markdown]
# # Regresión polinómica

# %% [markdown]
# # Importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression  # ¡No olvides importar LinearRegression!

# Importamos de la librería sklearn, la función train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Importar el data set

# %%
dataset = pd.read_csv('../data/student_scores.csv')
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# TODO: Define las variables X e y
# Tip: X debería ser la primera columna (horas de estudio) con reshape(-1, 1)
# y debería ser la segunda columna (puntuaciones)

X = # Tu código aquí
y = # Tu código aquí

# %%
# TODO: Divide el dataset en conjuntos de entrenamiento y prueba
# Tip: Usa test_size = 1/3 y random_state = 0 para reproducibilidad

X_train, X_test, y_train, y_test = # Tu código aquí

# %%
# Verificar las dimensiones de los conjuntos
print("Dimensiones:")
print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")

# %% [markdown]
# ## Ajustar la regresión polinómica
#
# En esta sección crearemos una función para realizar regresión polinómica de diferentes grados y evaluar su rendimiento.

# %%
def polynomial_regresion(X_test, X_train, y_train, y_test, degree):
    """
    Función para realizar regresión polinómica
    
    Pasos a implementar:
    1. Crear las características polinómicas usando PolynomialFeatures
    2. Transformar X_train con fit_transform
    3. Crear y entrenar el modelo LinearRegression
    4. Predecir en conjunto de entrenamiento y calcular R²
    5. Predecir en conjunto de prueba y calcular R²
    6. Retornar las predicciones
    """
    
    # TODO: Paso 1 - Crear PolynomialFeatures con el grado especificado
    poly_features = # Tu código aquí
    
    # TODO: Paso 2 - Transformar los datos de entrenamiento
    X_train_poly = # Tu código aquí
    
    # TODO: Paso 3 - Crear y entrenar el modelo de regresión lineal
    poly_model = # Tu código aquí
    # Entrenar el modelo: Tu código aquí
    
    # TODO: Paso 4 - Predecir en entrenamiento y calcular R²
    y_train_predict = # Tu código aquí
    r2_train = # Tu código aquí (usa r2_score)
    print(f"R² train: {r2_train}")

    # TODO: Paso 5 - Predecir en prueba y calcular R²
    y_test_predict = # Tu código aquí (recuerda transformar X_test)
    r2_test = # Tu código aquí
    print(f"R² test: {r2_test}")
    
    return y_train_predict, y_test_predict

# %%
# TODO: Prueba la función con un polinomio de grado 4
# Tip: Pasa todos los parámetros necesarios: X_test, X_train, y_train, y_test, degree=4

y_train_pred, y_test_pred = # Tu código aquí

# %% [markdown]
# ## Visualización de los resultados
#
# Vamos a visualizar qué tan bien se ajusta nuestro modelo polinómico a los datos.

# %% [markdown]
# ### Resultados en el conjunto de entrenamiento

# %%
# TODO: Crear scatter plot para el conjunto de entrenamiento
# Tip: Usa plt.scatter() dos veces:
# 1. Para los valores reales (X_train, y_train) en color rojo
# 2. Para las predicciones (X_train, y_train_pred) en color azul

plt.figure(figsize=(10, 6))

# Tu código aquí para el scatter plot de valores reales
# Tu código aquí para el scatter plot de predicciones

plt.title("Modelo de Regresión Polinómica - Entrenamiento")
plt.xlabel("Horas de estudio")
plt.ylabel("Puntuaciones")
plt.legend(["Valores reales", "Predicciones"])
plt.show()

# %% [markdown]
# ### Resultados en el conjunto de prueba

# %%
# TODO: Crear scatter plot para el conjunto de prueba
# Tip: Similar al anterior pero usando X_test, y_test, y_test_pred

plt.figure(figsize=(10, 6))

# Tu código aquí para el scatter plot de valores reales del test
# Tu código aquí para el scatter plot de predicciones del test

plt.title("Modelo de Regresión Polinómica - Prueba")
plt.xlabel("Horas de estudio")
plt.ylabel("Puntuaciones")
plt.legend(["Valores reales", "Predicciones"])
plt.show()

# %% [markdown]
# ## Ejercicios adicionales
#
# Una vez que hayas completado el ejercicio básico, puedes probar los siguientes retos:

# %%
# Reto 1: Prueba diferentes grados polinómicos (1, 2, 3, 4, 5)
# y compara los valores de R² para ver cuál funciona mejor

degrees = [1, 2, 3, 4, 5]
results = []

print("Comparación de diferentes grados polinómicos:")
print("=" * 50)

for degree in degrees:
    print(f"\nGrado {degree}:")
    # Tu código aquí
    
    # Opcional: Almacenar resultados para análisis posterior
    # results.append((degree, r2_train, r2_test))

# %%
# Reto 2: Crear una curva suave para la visualización
# Tip: Genera un rango de valores X más denso para obtener una curva más suave

# TODO: Crear un rango de valores X más denso para la visualización
X_range = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)

# TODO: Usar tu función polynomial_regresion o recrear el proceso 
# para generar predicciones sobre X_range

# TODO: Crear un gráfico que muestre:
# 1. Los puntos originales de entrenamiento
# 2. Los puntos originales de prueba  
# 3. La curva polinómica suave

plt.figure(figsize=(12, 8))
# Tu código aquí para el gráfico mejorado
plt.title("Regresión Polinómica con Curva Suave")
plt.xlabel("Horas de estudio")
plt.ylabel("Puntuaciones")
plt.legend()
plt.show()

# %% [markdown]
# ## Preguntas para reflexionar
#
# 1. **¿Qué sucede cuando aumentamos el grado del polinomio?**
#    - Observa cómo cambian los valores de R² en entrenamiento vs prueba
#
# 2. **¿Cuál es el grado óptimo para este dataset?**
#    - ¿Cuál balancea mejor el rendimiento en entrenamiento y prueba?
#
# 3. **¿Observas signos de overfitting o underfitting?**
#    - ¿En qué grados polinómicos ocurren?
#
# 4. **¿Qué ventajas y desventajas tiene la regresión polinómica vs la lineal simple?**
