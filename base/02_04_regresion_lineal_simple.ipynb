# %% [markdown]
# # 📊 REGRESIÓN LINEAL SIMPLE - Ejercicio Práctico
#
# ## 🎯 Objetivo del Ejercicio
#
# En este notebook aprenderás a implementar y evaluar un modelo de **regresión lineal simple** usando Python y scikit-learn.
#
# **Lo que vas a aprender:**
# - Predecir una variable continua basándose en otra variable
# - Encontrar la relación lineal entre dos variables
# - Evaluar la calidad del modelo mediante métricas estadísticas
# - Analizar residuales para validar supuestos
#
# ## 🏠 Caso de Estudio
# Utilizaremos datos de precios de casas para predecir el **precio por metro cuadrado** basándose en los **años de antigüedad** de la propiedad.
#
# **Ecuación que buscamos:** `Precio/m² = β₀ + β₁ × Años_antigüedad`

# %% [markdown]
# # 📚 1. Importar las librerías necesarias
#
# **💡 Tip:** Es una buena práctica importar todas las librerías al inicio para tener una visión clara de las dependencias del proyecto.

# %%
# Importamos las librerías necesarias para el análisis de regresión lineal simple
import numpy as np         # Para operaciones numéricas y manejo de arrays
import matplotlib.pyplot as plt  # Para visualización de datos y resultados
import pandas as pd        # Para manipulación y análisis de datos estructurados

# Importamos de la librería sklearn, la función train_test_split
# Esta función nos permite dividir automáticamente nuestros datos en conjuntos de entrenamiento y prueba
from sklearn.model_selection import train_test_split

# Importamos la función StandardScaler para normalizar las variables
from sklearn.preprocessing import StandardScaler

# Importamos la función LinearRegression de la librería sklearn para crear nuestro modelo de regresión
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 📁 2. Cargar y explorar el dataset
#
# **🔍 Pregunta clave:** ¿Esperamos que casas más antiguas tengan precios más altos o más bajos por metro cuadrado?

# %% [markdown]
# ## Descripción del dataset
#
# Este conjunto de datos contiene información sobre precios de casas por metro cuadrado en función de los años de antigüedad de cada propiedad.
#
# - **Variable independiente (X)**: Años de antigüedad de la casa
# - **Variable dependiente (y)**: Precio por metro cuadrado
# - **Objetivo**: Predecir el precio/m² basándose en la antigüedad de la propiedad

# %%
dataset = pd.read_csv("../data/precio_casas.csv")

# %%
# 📊 TODO: Exploración inicial de los datos
# Completa el siguiente código para explorar el dataset

# 1. Muestra las primeras filas del dataset
# ___TU_CÓDIGO_AQUÍ___

# 2. Obtén información básica sobre el dataset (shape, info, describe)
# ___TU_CÓDIGO_AQUÍ___

# 3. Verifica si hay valores nulos
# ___TU_CÓDIGO_AQUÍ___

# %% [markdown]
# **💡 Tip para el ejercicio anterior:**
# - Usa `dataset.head()` para ver las primeras filas
# - Usa `dataset.info()` y `dataset.describe()` para estadísticas básicas
# - Usa `dataset.isnull().sum()` para verificar valores nulos

# %%
# 🔍 TODO: Separar variables X e y
# Completa el siguiente código para separar las variables

# Separa las variables independientes (X) y la variable dependiente (y)
# X: Variable independiente - años de antigüedad de la casa (todas las columnas excepto la última)
# y: Variable dependiente - precio por metro cuadrado (segunda columna del dataset)

X = # ___TU_CÓDIGO_AQUÍ___ (pista: usa iloc[:, :-1].values)
y = # ___TU_CÓDIGO_AQUÍ___ (pista: usa iloc[:, 1].values)

# Verifica las dimensiones
print(f"Dimensiones de X: {X.shape}")
print(f"Dimensiones de y: {y.shape}")

# %% [markdown]
# # 🔄 3. División de datos: Entrenamiento vs Prueba
#
# ## ¿Por qué dividir los datos?
#
# La división de datos es **crucial** en machine learning para:
# 1. **Entrenar** el modelo con una porción de los datos
# 2. **Evaluar** su rendimiento en datos que nunca ha visto
# 3. **Evitar el sobreajuste** (overfitting)
#
# ## 📊 Estrategia de división
# - **🎓 Conjunto de entrenamiento** (67%): Datos que el modelo usará para aprender
# - **🧪 Conjunto de prueba** (33%): Datos que usaremos para evaluar el modelo

# %%
# 🎲 TODO: Dividir los datos en entrenamiento y prueba
# Completa el siguiente código

# Dividimos el dataset en conjuntos de entrenamiento y prueba
# - 67% de los datos para entrenamiento (test_size = 1/3)
# - 33% de los datos para prueba 
# random_state=0 asegura reproducibilidad de los resultados

X_train, X_test, y_train, y_test = train_test_split(
    # ___TU_CÓDIGO_AQUÍ___
    # Pista: (X, y, test_size=1/3, random_state=0)
)

# Verificamos las dimensiones de nuestros conjuntos de datos
print("Dimensiones de los conjuntos:")
print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")
print(f"Total de muestras de entrenamiento: {len(X_train)}")
print(f"Total de muestras de prueba: {len(X_test)}")

# %% [markdown]
# # 🤖 4. Creación y entrenamiento del modelo
#
# ## 🧠 ¿Cómo aprende el modelo?
#
# El modelo de regresión lineal utiliza el **método de mínimos cuadrados** para encontrar la mejor línea recta que se ajuste a los datos.
#
# **Resultado esperado:** Al final tendremos una ecuación del tipo:
# `Precio/m² = β₀ + β₁ × Años_antigüedad`

# %%
# 🎯 TODO: Crear y entrenar el modelo
# Completa el siguiente código

# Creamos una instancia del modelo de regresión lineal
regression = # ___TU_CÓDIGO_AQUÍ___ (pista: LinearRegression())

# Entrenamos el modelo con los datos de entrenamiento
# ___TU_CÓDIGO_AQUÍ___ (pista: usa el método .fit() con X_train y y_train)

print("✅ ¡Modelo entrenado exitosamente!")
print("El modelo ha aprendido la relación entre años de antigüedad y precio/m²")

# %% [markdown]
# # 🔮 5. Realizar predicciones en el conjunto de prueba
#
# **🎲 Momento de la verdad:** Este es el momento crucial donde descubrimos si nuestro modelo generaliza bien a datos nuevos.

# %%
# 🔮 TODO: Realizar predicciones
# Completa el siguiente código

# Realizamos predicciones sobre el conjunto de prueba
y_pred = # ___TU_CÓDIGO_AQUÍ___ (pista: usa regression.predict(X_test))

print(f"✅ Predicciones realizadas para {len(y_pred)} casas")
print(f"Ejemplo de las primeras 5 predicciones: {y_pred[:5]}")

# %% [markdown]
# # 📊 6. Visualización de resultados
#
# ## 🔍 ¿Qué observar en las gráficas?
#
# ### ✅ Signos de un buen ajuste:
# - Los puntos rojos están **cerca** de la línea azul
# - La línea azul pasa por el **centro** de la nube de puntos
# - No hay patrones evidentes en los residuos
#
# ### ⚠️ Signos de problemas:
# - Los puntos están muy **dispersos** respecto a la línea
# - La relación parece **no lineal** (curva en lugar de recta)

# %%
# 📈 TODO: Visualizar resultados del entrenamiento
# Completa el siguiente código para crear la gráfica

plt.figure(figsize=(12, 5))

# Subplot 1: Resultados del entrenamiento
plt.subplot(1, 2, 1)
# ___TU_CÓDIGO_AQUÍ___ (pista: usa plt.scatter(X_train, y_train, color="red"))
# ___TU_CÓDIGO_AQUÍ___ (pista: usa plt.plot(X_train, regression.predict(X_train), color="blue"))
plt.title("Precio/m² vs Años de antigüedad (Conjunto de Entrenamiento)")
plt.xlabel("Años de antigüedad")
plt.ylabel("Precio/m²")
plt.legend(["Línea de regresión", "Datos reales"])
plt.grid(True, alpha=0.3)

# Subplot 2: Resultados en datos de prueba  
plt.subplot(1, 2, 2)
# ___TU_CÓDIGO_AQUÍ___ (pista: usa plt.scatter(X_test, y_test, color="red"))
# ___TU_CÓDIGO_AQUÍ___ (pista: usa plt.plot(X_test, y_pred, color="blue"))
plt.title("Precio/m² vs Años de antigüedad (Conjunto de Prueba)")
plt.xlabel("Años de antigüedad")
plt.ylabel("Precio/m²")
plt.legend(["Predicciones", "Datos reales"])
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 🎯 7. Evaluación del modelo con métricas
#
# ## 📈 R² Score (Coeficiente de Determinación)
#
# El **R²** es la métrica más importante para evaluar modelos de regresión:
#
# > **"¿Qué porcentaje de la variabilidad en los precios puede explicar nuestro modelo?"**
#
# ### Interpretación del R²:
# - **R² = 1.0** → 🎯 **Modelo perfecto** (100% de la variabilidad)
# - **R² = 0.8** → ✅ **Excelente modelo** (80% de la variabilidad)
# - **R² = 0.6** → ✅ **Buen modelo** (60% de la variabilidad)
# - **R² = 0.4** → ⚠️ **Modelo moderado** (40% de la variabilidad)
# - **R² = 0.0** → ❌ **Modelo inútil** (no mejor que usar la media)

# %%
# 📊 TODO: Calcular métricas de evaluación
# Completa el siguiente código

# Importamos las métricas necesarias
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Calculamos el R² score para evaluar la calidad del modelo
r2 = # ___TU_CÓDIGO_AQUÍ___ (pista: r2_score(y_test, y_pred))

# Calculamos otras métricas importantes
mse = # ___TU_CÓDIGO_AQUÍ___ (pista: mean_squared_error(y_test, y_pred))
rmse = # ___TU_CÓDIGO_AQUÍ___ (pista: np.sqrt(mse))
mae = # ___TU_CÓDIGO_AQUÍ___ (pista: mean_absolute_error(y_test, y_pred))

print("=== MÉTRICAS DE EVALUACIÓN DEL MODELO ===")
print(f"R² Score: {r2:.4f}")
print(f"  → El modelo explica el {r2*100:.2f}% de la variabilidad")
print(f"MSE (Error Cuadrático Medio): {mse:.2f}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse:.2f}")
print(f"  → Error promedio en las predicciones: ±{rmse:.2f} unidades")
print(f"MAE (Error Absoluto Medio): {mae:.2f}")

print("\n=== CALIDAD DEL MODELO ===")
if r2 > 0.8:
    print("✅ Excelente ajuste del modelo")
elif r2 > 0.6:
    print("✅ Buen ajuste del modelo") 
elif r2 > 0.4:
    print("⚠️ Ajuste moderado del modelo")
else:
    print("❌ Ajuste pobre del modelo")

# %% [markdown]
# # 🔬 8. Análisis de los parámetros del modelo
#
# **🧮 ¡Vamos a "abrir la caja negra" del modelo!** Aquí descubriremos la ecuación exacta que está usando nuestro modelo.

# %%
# 🔍 TODO: Analizar los parámetros del modelo
# Completa el siguiente código

# Obtenemos los parámetros del modelo entrenado
intercept = # ___TU_CÓDIGO_AQUÍ___ (pista: regression.intercept_)
coef = # ___TU_CÓDIGO_AQUÍ___ (pista: regression.coef_[0])

print("=== ECUACIÓN DE LA RECTA DE REGRESIÓN ===")
print(f"y = {intercept:.2f} + ({coef:.2f}) * x")
print(f"Precio/m² = {intercept:.2f} + ({coef:.2f}) * Años_antiguedad")
print()

print("=== INTERPRETACIÓN DE LOS COEFICIENTES ===")
print(f"• Intercept (β₀): {intercept:.2f}")
print(f"  → Precio esperado por m² cuando la casa es nueva (0 años)")
print(f"• Pendiente (β₁): {coef:.2f}")
if coef < 0:
    print(f"  → Por cada año adicional de antigüedad, el precio disminuye en {abs(coef):.2f} unidades")
else:
    print(f"  → Por cada año adicional de antigüedad, el precio aumenta en {coef:.2f} unidades")

print("\n💭 REFLEXIÓN:")
print("¿Tiene sentido lógico esta relación? ¿Las casas más antiguas valen más o menos?")

# %% [markdown]
# # 🚀 9. Predicciones con nuevos datos
#
# **🎯 ¡Es hora de usar nuestro modelo entrenado para hacer predicciones reales!**
#
# Imagina que eres un agente inmobiliario y necesitas estimar precios para casas con diferentes antigüedades.

# %%
# 🏠 TODO: Hacer predicciones con nuevas casas
# Completa el siguiente código

# Ejemplo práctico: predecir el precio de casas con diferentes antigüedades
nuevas_antigüedades = np.array([[5], [10], [15], [25]])

# Realizamos las predicciones
nuevas_predicciones = # ___TU_CÓDIGO_AQUÍ___ (pista: regression.predict(nuevas_antigüedades))

print("=== PREDICCIONES PARA NUEVAS CASAS ===")
for i, (antiguedad, precio) in enumerate(zip(nuevas_antigüedades.flatten(), nuevas_predicciones)):
    print(f"Casa de {antiguedad} años: {precio:.2f} unidades por m²")

print()
print("=== VERIFICACIÓN MANUAL DE LA FÓRMULA ===")
print("Usando la ecuación: y = {:.2f} + ({:.2f}) * x".format(intercept, coef))
for antiguedad in nuevas_antigüedades.flatten():
    # TODO: Calcula el precio manualmente usando la ecuación
    precio_manual = # ___TU_CÓDIGO_AQUÍ___ (pista: intercept + coef * antiguedad)
    print(f"Casa de {antiguedad} años: {precio_manual:.2f} unidades por m² (calculado manualmente)")

# %% [markdown]
# # 🔍 10. EJERCICIO AVANZADO (Opcional): Análisis de Residuales
#
# **Para estudiantes ambiciosos:** Los residuales nos ayudan a validar si nuestro modelo cumple con los supuestos de la regresión lineal.

# %%
# 📊 TODO AVANZADO: Análisis de residuales (Opcional)
# Este ejercicio es para estudiantes que quieren profundizar más

# Los residuales son la diferencia entre valores reales y predicciones
residuales = y_test - y_pred

# Crear gráfico de residuales
plt.figure(figsize=(10, 4))

# Subplot 1: Residuales vs Predicciones
plt.subplot(1, 2, 1) 
# ___TU_CÓDIGO_AQUÍ___ Crear scatter plot de y_pred vs residuales
plt.axhline(y=0, color='red', linestyle='--', label='y=0')
plt.xlabel('Valores Predichos')
plt.ylabel('Residuales') 
plt.title('Residuales vs Predicciones')
plt.legend()
plt.grid(True, alpha=0.3)

# Subplot 2: Histograma de residuales
plt.subplot(1, 2, 2)
# ___TU_CÓDIGO_AQUÍ___ Crear histograma de residuales
plt.xlabel('Residuales')
plt.ylabel('Frecuencia')
plt.title('Distribución de Residuales')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("=== ANÁLISIS DE RESIDUALES ===")
print(f"Media de residuales: {np.mean(residuales):.6f} (debe estar cerca de 0)")
print(f"Desviación estándar: {np.std(residuales):.4f}")
print("\n✅ BUENO: Si los residuales están distribuidos aleatoriamente alrededor de 0")
print("❌ MALO: Si hay patrones evidentes en los residuales")

# %% [markdown]
# # 🎓 11. Conclusiones y próximos pasos
#
# ## ✅ Lo que has logrado
#
# En este ejercicio has completado un **flujo completo de machine learning**:
#
# 1. ✅ **Carga de datos** y exploración inicial
# 2. ✅ **División** en conjuntos de entrenamiento y prueba
# 3. ✅ **Entrenamiento** de un modelo de regresión lineal simple
# 4. ✅ **Predicciones** en datos no vistos
# 5. ✅ **Visualización** de resultados
# 6. ✅ **Evaluación** con métricas (R², MSE, RMSE, MAE)
# 7. ✅ **Análisis profundo** de parámetros del modelo
# 8. ✅ **Aplicación práctica** con nuevos datos
# 9. ✅ **Análisis de residuales** (opcional)
#
# ## 🧠 Conceptos clave aprendidos
#
# - **Ecuación de regresión lineal**: y = β₀ + β₁x
# - **Método de mínimos cuadrados** para encontrar la mejor línea
# - **División train/test** para evitar overfitting
# - **R² como métrica principal** de evaluación
# - **Interpretación de coeficientes** para entender el modelo
#
# ## 💭 Preguntas de reflexión
#
# 1. ¿Tu modelo tiene un R² aceptable (>0.6)?
# 2. ¿Los coeficientes tienen sentido lógico?
# 3. ¿Los residuales se distribuyen aleatoriamente?
# 4. ¿Podrías explicar los resultados a alguien sin conocimientos técnicos?
#
# ## 🚀 Próximos pasos
#
# Para profundizar en regresión:
# - 🔍 **Regresión múltiple**: Usar múltiples variables predictoras
# - 📊 **Validación cruzada**: Técnicas más robustas de evaluación
# - 🛠️ **Preprocesamiento**: Normalización, tratamiento de outliers
# - 🤖 **Otros modelos**: Random Forest, SVM, etc.

# %%
# 🎉 ¡Felicitaciones! Has completado el ejercicio de regresión lineal simple

# Aquí puedes hacer pruebas adicionales o experimentar con el modelo
# Por ejemplo:

# 1. Probar con diferentes valores de antigüedad
# 2. Analizar qué pasaría con casas muy nuevas (0-2 años) o muy antiguas (30+ años)
# 3. Comparar las predicciones con tu intuición sobre el mercado inmobiliario

print("🎊 ¡Excelente trabajo!")
print("Has completado tu primer modelo de regresión lineal simple.")
print("🚀 ¡Ahora estás listo para problemas más avanzados!")
